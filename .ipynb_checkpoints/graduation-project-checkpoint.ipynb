# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("composites.csv")

# %%
df
# Out:
#             x          y       z        Ni
# 0    243684.0  1717695.0  388.60  2.180000
# 1    243684.0  1717695.0  385.60  2.180000
# 2    243684.0  1717695.0  382.60  2.180000
# 3    243684.0  1717695.0  379.60  2.133333
# 4    243684.0  1717695.0  376.60  2.040000
# ..        ...        ...     ...       ...
# 382  243435.1  1717869.9  385.20  1.980000
# 383  243495.4  1717905.7  401.58  1.850000
# 384  243495.4  1717905.7  398.58  1.850000
# 385  243497.0  1717708.0  386.14  2.259000
# 386  243497.0  1717708.0  383.14  2.630000
#
# [387 rows x 4 columns]

# %%
df['Ni'].describe()
# Out:
# count    387.000000
# mean       2.097379
# std        0.351767
# min        1.310000
# 25%        1.860000
# 50%        2.030000
# 75%        2.360000
# max        3.030000
# Name: Ni, dtype: float64

# %%
y = df["Ni"].values

# %%
x = df.drop("Ni", axis=1).values

# %%
df_x = pd.DataFrame(x)

# %%
df_x
# Out:
#             0          1       2
# 0    243684.0  1717695.0  388.60
# 1    243684.0  1717695.0  385.60
# 2    243684.0  1717695.0  382.60
# 3    243684.0  1717695.0  379.60
# 4    243684.0  1717695.0  376.60
# ..        ...        ...     ...
# 382  243435.1  1717869.9  385.20
# 383  243495.4  1717905.7  401.58
# 384  243495.4  1717905.7  398.58
# 385  243497.0  1717708.0  386.14
# 386  243497.0  1717708.0  383.14
#
# [387 rows x 3 columns]

# %%
df_y = pd.DataFrame(y)

# %%
df_y
# Out:
#             0
# 0    2.180000
# 1    2.180000
# 2    2.180000
# 3    2.133333
# 4    2.040000
# ..        ...
# 382  1.980000
# 383  1.850000
# 384  1.850000
# 385  2.259000
# 386  2.630000
#
# [387 rows x 1 columns]

# %%
df_y.mean()
# Out:
# 0    2.097379
# dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (309, 3)
# (309,)
# (78, 3)
# (78,)

# %%
y_train.shape
# Out:
# (309,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Activation,Dropout
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import keras
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import RMSprop
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
x_train
# Out:
# array([[2.43534000e+05, 1.71769500e+06, 4.02300000e+02],
#        [2.43433600e+05, 1.71781880e+06, 3.91130000e+02],
#        [2.43584000e+05, 1.71789500e+06, 4.05100000e+02],
#        [2.43634000e+05, 1.71764500e+06, 3.85600000e+02],
#        [2.43559000e+05, 1.71789500e+06, 4.08100000e+02],
#        [2.43584000e+05, 1.71769500e+06, 4.03900000e+02],
#        [2.43634000e+05, 1.71782000e+06, 4.00800000e+02],
#        [2.43559000e+05, 1.71769500e+06, 4.00200000e+02],
#        [2.43584000e+05, 1.71767000e+06, 3.88800000e+02],
#        [2.43534000e+05, 1.71767000e+06, 4.01600000e+02],
#        [2.43384700e+05, 1.71777050e+06, 3.89620000e+02],
#        [2.43534000e+05, 1.71774500e+06, 3.95700000e+02],
#        [2.43410100e+05, 1.71779380e+06, 3.87180000e+02],
#        [2.43659300e+05, 1.71794500e+06, 4.14700000e+02],
#        [2.43484000e+05, 1.71769500e+06, 4.07100000e+02],
#        [2.43484000e+05, 1.71762000e+06, 3.89800000e+02],
# ...

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)

# %%
scaler_2 = MinMaxScaler()

# %%
x_train
# Out:
# array([[-0.45681289, -0.68349576,  0.26711201],
#        [-1.80412579,  0.42140929, -0.97192832],
#        [ 0.21415968,  1.10148816,  0.57770404],
#        [ 0.88513224, -1.12974174, -1.58534758],
#        [-0.12132661,  1.10148816,  0.91048121],
#        [ 0.21415968, -0.68349576,  0.44459317],
#        [ 0.88513224,  0.43211919,  0.10072343],
#        [-0.12132661, -0.68349576,  0.03416799],
#        [ 0.21415968, -0.90661875, -1.23038526],
#        [-0.45681289, -0.90661875,  0.18946401],
#        [-2.46033696, -0.00966433, -1.13942621],
#        [-0.45681289, -0.23724978, -0.46499776],
#        [-2.1194829 ,  0.1982863 , -1.41008493],
#        [ 1.22464436,  1.54773414,  1.64259099],
#        [-1.12778545, -0.68349576,  0.79955549],
#        [-1.12778545, -1.35286473, -1.11945954],
#        [ 1.5561048 ,  0.2089962 ,  0.88829607],
#        [ 1.22061852,  0.87836517,  0.48896346],
#        [ 0.21415968, -0.46037277, -0.23205374],
#        [ 1.5561048 , -0.23724978, -0.62029378],
# ...

# %%
y_train
# Out:
# array([1.99    , 2.69    , 1.76    , 2.37    , 2.02    , 2.49    ,
#        1.68    , 2.2     , 2.14    , 1.996667, 2.1806  , 2.49    ,
#        2.95    , 1.95    , 2.51    , 2.23    , 2.73    , 2.03    ,
#        2.24    , 2.48    , 2.73    , 2.56    , 2.13    , 2.176666,
#        2.063333, 2.27    , 1.88    , 2.36    , 1.58    , 2.05    ,
#        1.956667, 1.92    , 2.56    , 2.49    , 2.09    , 1.68    ,
#        2.73    , 2.03    , 1.99    , 1.95    , 2.59    , 1.78    ,
#        1.95    , 2.15    , 2.72    , 2.34    , 2.47    , 1.98    ,
#        1.99    , 2.44    , 2.49    , 1.36    , 1.89    , 2.52    ,
#        2.36    , 1.57    , 2.003333, 2.18    , 2.03    , 1.61    ,
#        1.98    , 2.17    , 2.076667, 2.06    , 2.51    , 1.77    ,
#        2.56    , 1.4     , 2.36    , 2.48    , 1.79    , 2.08    ,
#        2.37    , 1.68    , 2.95    , 1.513333, 2.41    , 2.291667,
#        2.51    , 2.27    , 1.79    , 1.61    , 2.07    , 1.95    ,
# ...

# %%
x_test_raw = pd.DataFrame(x_test)
x_test_raw
# Out:
#            0          1      2
# 0   243484.0  1717620.0  395.8
# 1   243584.0  1717570.0  396.0
# 2   243634.0  1717720.0  400.4
# 3   243534.0  1717920.0  407.1
# 4   243559.0  1717695.0  406.2
# ..       ...        ...    ...
# 73  243684.0  1717795.0  401.9
# 74  243609.0  1717695.0  398.8
# 75  243534.0  1717970.0  406.5
# 76  243472.0  1717607.0  394.1
# 77  243659.0  1717845.0  398.5
#
# [78 rows x 3 columns]

# %%
x_test_raw.to_csv("x_test_raw.csv")

# %%
x_test = scaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[-1.19567545e+00, -1.44935693e+00, -6.04430695e-01],
#        [ 2.09318851e-02, -1.89933879e+00, -5.81647342e-01],
#        [ 6.29235551e-01, -5.49393229e-01, -8.04135550e-02],
#        [-5.87371781e-01,  1.25053418e+00,  6.82828802e-01],
#        [-2.83219948e-01, -7.74384155e-01,  5.80303709e-01],
#        [-8.91523614e-01,  5.75561404e-01,  1.17267091e+00],
#        [ 9.37037206e-01,  1.47552511e+00,  5.23345324e-01],
#        [ 6.29235551e-01, -9.94113755e-02,  8.53703956e-01],
#        [-8.91523614e-01, -1.44935693e+00, -1.18540622e+00],
#        [ 1.23753922e+00,  8.00552330e-01, -6.71816263e-04],
#        [ 9.33387384e-01,  1.02554326e+00,  1.36028307e-01],
#        [ 6.29235551e-01, -1.22436601e+00, -2.44988236e+00],
#        [-5.87371781e-01, -1.44935693e+00, -1.89169019e+00],
#        [ 1.23753922e+00,  1.70051604e+00,  1.26380433e+00],
#        [-2.40376653e+00, -9.49115570e-02, -1.65018680e+00],
#        [-5.87371781e-01,  5.75561404e-01,  1.59416296e+00],
# ...

# %%
y_train
# Out:
# array([1.99    , 2.69    , 1.76    , 2.37    , 2.02    , 2.49    ,
#        1.68    , 2.2     , 2.14    , 1.996667, 2.1806  , 2.49    ,
#        2.95    , 1.95    , 2.51    , 2.23    , 2.73    , 2.03    ,
#        2.24    , 2.48    , 2.73    , 2.56    , 2.13    , 2.176666,
#        2.063333, 2.27    , 1.88    , 2.36    , 1.58    , 2.05    ,
#        1.956667, 1.92    , 2.56    , 2.49    , 2.09    , 1.68    ,
#        2.73    , 2.03    , 1.99    , 1.95    , 2.59    , 1.78    ,
#        1.95    , 2.15    , 2.72    , 2.34    , 2.47    , 1.98    ,
#        1.99    , 2.44    , 2.49    , 1.36    , 1.89    , 2.52    ,
#        2.36    , 1.57    , 2.003333, 2.18    , 2.03    , 1.61    ,
#        1.98    , 2.17    , 2.076667, 2.06    , 2.51    , 1.77    ,
#        2.56    , 1.4     , 2.36    , 2.48    , 1.79    , 2.08    ,
#        2.37    , 1.68    , 2.95    , 1.513333, 2.41    , 2.291667,
#        2.51    , 2.27    , 1.79    , 1.61    , 2.07    , 1.95    ,
# ...

# %%
model = Sequential()

model.add(Dense(1024, activation="relu", kernel_initializer='glorot_uniform', input_dim=3,))

model.add(Dense(512, activation="relu", kernel_initializer='glorot_uniform'  ))
model.add(Dense(256, activation="relu", kernel_initializer='glorot_uniform' ))
model.add(Dense(256, activation="relu",  kernel_initializer='glorot_uniform'))
model.add(Dense(128, activation="relu",  kernel_initializer='glorot_uniform'))
model.add(Dense(64, activation="relu",  kernel_initializer='glorot_uniform'))



model.add(Dense(1, activation="softplus", kernel_initializer='glorot_uniform'))

# %%
adam = Adam(learning_rate=0.0001)
Adam = Adam(learning_rate=0.001, decay=1e-3 / 200)

# %%
sgd = SGD(learning_rate = 0.1, momentum=0.1)

# %%
rms = RMSprop(learning_rate = 0.0001, momentum = 0.0)

# %%
model.compile(loss='mse', optimizer = 'adam')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1024)              4096
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 256)               65792
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dense_6 (Dense)             (None, 1)                 65
#
# ...
# Total params: 767,233
# Trainable params: 767,233
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(x=x_train, y=y_train, epochs=10000, validation_data=(x_test, y_test),  verbose=1,  batch_size=50, callbacks =[es] )
# Out:
# Epoch 1/10000
# 7/7 [==============================] - 1s 37ms/step - loss: 1.3000 - val_loss: 0.4090
# Epoch 2/10000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.3553 - val_loss: 0.2917
# Epoch 3/10000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2609 - val_loss: 0.2663
# Epoch 4/10000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2499 - val_loss: 0.2155
# Epoch 5/10000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2551 - val_loss: 0.1974
# Epoch 6/10000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2329 - val_loss: 0.2732
# Epoch 7/10000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2292 - val_loss: 0.2486
# Epoch 8/10000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1918 - val_loss: 0.1801
# Epoch 9/10000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1601 - val_loss: 0.1571
# Epoch 10/10000
# ...

# %%
model.history.history
# Out:
# {'loss': [1.2999776601791382,
#   0.35531920194625854,
#   0.26094624400138855,
#   0.24991516768932343,
#   0.25508973002433777,
#   0.23293684422969818,
#   0.22921137511730194,
#   0.19184289872646332,
#   0.16005940735340118,
#   0.16230247914791107,
#   0.14318576455116272,
#   0.13200929760932922,
#   0.12806200981140137,
#   0.11744652688503265,
#   0.10955966264009476,
#   0.10307317972183228,
#   0.10547996312379837,
#   0.10036707669496536,
#   0.09266003966331482,
#   0.09742474555969238,
#   0.09280825406312943,
#   0.10037432610988617,
#   0.1208866611123085,
#   0.11264406889677048,
#   0.10834711790084839,
#   0.11387955397367477,
#   0.10058674961328506,
#   0.09115918725728989,
#   0.09044890105724335,
#   0.09361360967159271,
#   0.10240396857261658,
#   0.10550383478403091,
#   0.10603941231966019,
#   0.10982781648635864,
#   0.10653901100158691,
#   0.09748345613479614,
#   0.0871686190366745,
#   0.08292768895626068,
#   0.08197365701198578,
# ...

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss
# Out:
#          loss  val_loss
# 0    1.299978  0.409025
# 1    0.355319  0.291682
# 2    0.260946  0.266343
# 3    0.249915  0.215495
# 4    0.255090  0.197434
# ..        ...       ...
# 302  0.005534  0.107078
# 303  0.009282  0.122070
# 304  0.009801  0.107881
# 305  0.007552  0.129818
# 306  0.007861  0.113810
#
# [307 rows x 2 columns]

# %%
model_loss.plot()
# Out:
# <AxesSubplot:>

# %%
predicts = model.predict(x_test)

# %%
predicts
# Out:
# array([[1.858135 ],
#        [1.6826928],
#        [2.6351922],
#        [2.2978585],
#        [2.0311058],
#        [2.2382221],
#        [1.4545299],
#        [2.8289459],
#        [2.217458 ],
#        [2.071493 ],
#        [2.046067 ],
#        [2.6755846],
#        [2.0072505],
#        [2.0866709],
#        [2.1352956],
#        [1.8297322],
#        [1.9722915],
#        [2.26724  ],
#        [2.678077 ],
#        [2.3892603],
#        [1.9952723],
#        [1.8372226],
#        [2.2872179],
#        [2.254818 ],
#        [1.5400479],
#        [2.1363547],
#        [1.9288628],
#        [2.387809 ],
#        [1.929059 ],
#        [2.0602884],
#        [2.1232605],
#        [1.9992952],
#        [2.0169683],
#        [1.8232149],
#        [1.7150509],
#        [2.594421 ],
#        [1.94096  ],
#        [1.3898308],
#        [1.8673354],
#        [2.2094924],
#        [1.6683333],
#        [1.8031033],
#        [2.1569092],
#        [2.239989 ],
#        [1.8177834],
# ...

# %%
predicts.mean()
# Out:
# 2.1113768

# %%
y_test.mean()
# Out:
# 2.0725085384615385

# %%
print(predicts.min())
print(predicts.max())
# Out:
# 1.3898308
# 3.1697657

# %%
print(y_test.min())
print(y_test.max())
# Out:
# 1.36
# 3.03

# %%
y_test
# Out:
# array([2.096667, 1.64    , 1.873333, 2.36    , 2.053333, 2.43    ,
#        1.97    , 1.88    , 1.94    , 2.38    , 2.24    , 2.37    ,
#        2.45    , 1.97    , 2.36    , 1.67    , 2.21    , 2.24    ,
#        1.93    , 2.59    , 1.83    , 2.1     , 1.84    , 2.48    ,
#        1.573333, 2.276667, 1.433333, 2.306667, 1.63    , 2.18    ,
#        1.98    , 1.97    , 1.99    , 1.85    , 1.93    , 1.98    ,
#        1.83    , 1.36    , 2.      , 2.2     , 2.01    , 1.926667,
#        2.259   , 1.92    , 1.366667, 1.703333, 2.36    , 1.87    ,
#        2.61    , 2.38    , 2.11    , 1.64    , 1.95    , 1.84    ,
#        2.38    , 1.706667, 2.133333, 1.64    , 2.31    , 2.36    ,
#        3.03    , 1.85    , 2.43    , 1.79    , 2.293333, 2.27    ,
#        2.033333, 1.83    , 1.96    , 1.83    , 1.97    , 2.6     ,
#        2.133333, 2.73    , 2.99    , 1.73    , 2.266667, 2.05    ])

# %% [markdown]
# # Blok merkezleri denemesi

# %%
df_block = pd.read_csv("block_centroids.csv")

# %%
df_block
# Out:
#                  X            Y        Z
# 0       243411.841  1717604.588  392.872
# 1       243411.841  1717607.088  392.872
# 2       243411.841  1717604.588  395.372
# 3       243411.841  1717604.588  397.872
# 4       243411.841  1717607.088  395.372
# ...            ...          ...      ...
# 101793  243694.341  1717974.588  415.372
# 101794  243694.341  1717974.588  417.872
# 101795  243694.341  1717977.088  415.372
# 101796  243694.341  1717977.088  417.872
# 101797  243694.341  1717974.588  420.372
#
# [101798 rows x 3 columns]

# %%
block_test = df_block.values

# %%
block_test
# Out:
# array([[2.43411841e+05, 1.71760459e+06, 3.92872000e+02],
#        [2.43411841e+05, 1.71760709e+06, 3.92872000e+02],
#        [2.43411841e+05, 1.71760459e+06, 3.95372000e+02],
#        ...,
#        [2.43694341e+05, 1.71797709e+06, 4.15372000e+02],
#        [2.43694341e+05, 1.71797709e+06, 4.17872000e+02],
#        [2.43694341e+05, 1.71797459e+06, 4.20372000e+02]])

# %%
block_test_scaled = scaler.fit_transform(block_test)

# %%
block_test_scaled
# Out:
# array([[-1.59026888, -1.51858118, -0.73388206],
#        [-1.59026888, -1.49564285, -0.73388206],
#        [-1.59026888, -1.51858118, -0.44700476],
#        ...,
#        [ 1.49880228,  1.89923123,  1.84801364],
#        [ 1.49880228,  1.89923123,  2.13489094],
#        [ 1.49880228,  1.8762929 ,  2.42176824]])

# %%
block_predicts = model.predict(block_test_scaled)

# %%
block_predicts
# Out:
# array([[2.38683  ],
#        [2.3774645],
#        [2.2066553],
#        ...,
#        [2.0155044],
#        [1.7812071],
#        [1.6382544]], dtype=float32)

# %%
block_predicts.mean()
# Out:
# 2.0892868

# %%
block_predicts.min()
# Out:
# 1.1928798

# %%
block_predicts.max()
# Out:
# 3.4977903

# %%
df_block_predicts = pd.DataFrame(block_predicts)

# %%
df_block_predicts
# Out:
#                0
# 0       2.386830
# 1       2.377465
# 2       2.206655
# 3       1.791563
# 4       2.227623
# ...          ...
# 101793  2.008274
# 101794  1.777454
# 101795  2.015504
# 101796  1.781207
# 101797  1.638254
#
# [101798 rows x 1 columns]

# %%
df_y.describe()
# Out:
#                 0
# count  387.000000
# mean     2.097379
# std      0.351767
# min      1.310000
# 25%      1.860000
# 50%      2.030000
# 75%      2.360000
# max      3.030000

# %%
df_block_predicts.describe()
# Out:
#                    0
# count  101798.000000
# mean        2.089295
# std         0.325278
# min         1.192880
# 25%         1.870152
# 50%         2.054703
# 75%         2.309112
# max         3.497790

# %%
sbn.distplot(x=block_predicts )
# Out:
# C:\Users\enesc\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sbn.distplot(x=df_y )
# Out:
# C:\Users\enesc\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
df_block_predicts.to_csv("block_predicts_2.csv")

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(x_train, y_train)

# %%
reg.score
# Out:
# <bound method RegressorMixin.score of LinearRegression()>

# %%
reg.predict(x_test)
# Out:
# array([2.19436031, 2.18512565, 2.11200495, 2.02475116, 2.05543129,
#        1.98492956, 2.02357416, 2.01051082, 2.25128581, 2.08236322,
#        2.06869921, 2.36413024, 2.32113749, 1.94165563, 2.29871339,
#        1.93844565, 2.1286421 , 2.033446  , 2.06130917, 2.04573222,
#        2.03079054, 2.07901887, 2.20693465, 2.24561531, 1.9938908 ,
#        1.97490578, 2.01765934, 2.20466753, 2.1758615 , 2.24722535,
#        2.15811997, 1.95306774, 1.99797299, 1.95001575, 2.02052217,
#        2.05609071, 2.06604375, 2.11496566, 2.23461919, 2.10022207,
#        1.98417695, 2.05281233, 2.29727484, 2.04324997, 2.04445924,
#        1.96241922, 2.33396658, 1.99553734, 2.04519473, 2.0118568 ,
#        1.97730961, 2.22037885, 2.21776458, 1.94828143, 1.97660359,
#        1.98954455, 2.18608563, 2.03676395, 2.08929427, 2.09525758,
#        2.29798719, 2.09572542, 2.14769544, 2.01865348, 2.14947401,
#        2.18934221, 2.02652739, 2.35034664, 2.04950682, 2.27984022,
# ...

# %%
from sklearn import metrics


def eval_clf(y_true, y_pred):
    acc = metrics.accuracy_score(y_true, y_pred)
    p = metrics.precision_score(y_true, y_pred)
    r = metrics.recall_score(y_true, y_pred)
    f1 = metrics.f1_score(y_true, y_pred)
    
    result = {
        'acc': acc,
        'p': p,
        'r': r,
        'f1': f1
    }
    
    return result


def eval_auc(y_true, y_prob):
    fpr, tpr, thresholds = metrics.roc_curve(y_true, y_prob)
    precision, recall, thresholds = metrics.precision_recall_curve(y_true, y_prob)
    
    roc_auc = metrics.auc(fpr, tpr)
    pr_auc = metrics.auc(recall, precision)
    
    result = {
        'roc_auc': roc_auc,
        'pr_auc': pr_auc
    }
    
    return result

    
def eval_threshold(y_true, y_prob, threshold):
    y_pred = np.where(np.array(y_prob) > threshold, 1, 0)

    return eval_clf(y_true, y_pred)

# %%
# TEST

dummy_y_true = [1, 1, 1, 0, 0, 0]
dummy_y_pred = [1, 1, 0, 1, 1, 0]
dummy_y_prob = [0.95, 0.55, 0.05, 0.55, 0.65, 0.10]


print('-' * 10)
print('res_clf')
res_clf = eval_clf(dummy_y_true, dummy_y_pred)
print(res_clf)

print('-' * 10)
print('res_auc')
res_auc = eval_auc(dummy_y_true, dummy_y_prob)
print(res_auc)

print('-' * 10)
print('res_thr threshold=0.5')
res_thr = eval_threshold(dummy_y_true, dummy_y_prob, threshold=0.5)
print(res_thr)

print('-' * 10)
print('res_thr threshold=0.70')
res_thr = eval_threshold(dummy_y_true, dummy_y_prob, threshold=0.7)
print(res_thr)
# Out:
# ----------
# res_clf
# {'acc': 0.5, 'p': 0.5, 'r': 0.6666666666666666, 'f1': 0.5714285714285715}
# ----------
# res_auc
# {'roc_auc': 0.5, 'pr_auc': 0.6499999999999999}
# ----------
# res_thr threshold=0.5
# {'acc': 0.5, 'p': 0.5, 'r': 0.6666666666666666, 'f1': 0.5714285714285715}
# ----------
# res_thr threshold=0.70
# {'acc': 0.6666666666666666, 'p': 1.0, 'r': 0.3333333333333333, 'f1': 0.5}

# %%
y_pred = reg.predict(x_test)


print('y_pred')
print(y_pred)
# Out:
# y_pred
# [2.19436031 2.18512565 2.11200495 2.02475116 2.05543129 1.98492956
#  2.02357416 2.01051082 2.25128581 2.08236322 2.06869921 2.36413024
#  2.32113749 1.94165563 2.29871339 1.93844565 2.1286421  2.033446
#  2.06130917 2.04573222 2.03079054 2.07901887 2.20693465 2.24561531
#  1.9938908  1.97490578 2.01765934 2.20466753 2.1758615  2.24722535
#  2.15811997 1.95306774 1.99797299 1.95001575 2.02052217 2.05609071
#  2.06604375 2.11496566 2.23461919 2.10022207 1.98417695 2.05281233
#  2.29727484 2.04324997 2.04445924 1.96241922 2.33396658 1.99553734
#  2.04519473 2.0118568  1.97730961 2.22037885 2.21776458 1.94828143
#  1.97660359 1.98954455 2.18608563 2.03676395 2.08929427 2.09525758
#  2.29798719 2.09572542 2.14769544 2.01865348 2.14947401 2.18934221
#  2.02652739 2.35034664 2.04950682 2.27984022 1.98832095 2.09681634
#  2.35298498 2.0806654  2.1363793  2.02666645 2.2171147  2.11848863]

# %%
# print('-' * 10)
# print('res_clf')
# res_clf = eval_clf(y_test, y_pred)
# print(res_clf)

print('-' * 10)
print('res_clf')
res_clf = eval_clf(y_test, y_pred)
print(res_clf)

print('-' * 10)
print('res_auc')
res_auc = eval_auc(y_test, y_pred)
print(res_auc)
# Out:
# ----------
# res_clf
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6164/2180441655.py in <module>
#       6 print('-' * 10)
#       7 print('res_clf')
# ----> 8 res_clf = eval_clf(y_test, y_pred)
#       9 print(res_clf)
#      10
#
# ~\AppData\Local\Temp/ipykernel_6164/2698139643.py in eval_clf(y_true, y_pred)
#       3
#       4 def eval_clf(y_true, y_pred):
# ----> 5     acc = metrics.accuracy_score(y_true, y_pred)
#       6     p = metrics.precision_score(y_true, y_pred)
#       7     r = metrics.recall_score(y_true, y_pred)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     209
#     210     # Compute accuracy for each possible representation
# --> 211     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
# ...
